# %% [markdown]
# <a href="https://colab.research.google.com/github/FNAGHAV/Alphabet-Soup-Funding-Prediction/blob/main/AlphabetSoupCharity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import dependencies

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import make_scorer
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# Import and read charity_data.csv

application_df = pd.read_csv('https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv')
application_df.head(5)
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Binning ASK_AMT column
application_df['ASK_AMT_Binned'] = pd.cut(application_df['ASK_AMT'], bins=1000, labels=False)

# Finding the range of values for bin 0
bin_0_values = application_df.loc[application_df['ASK_AMT_Binned'] == 17, 'ASK_AMT']
bin_0_min = bin_0_values.min()
bin_0_max = bin_0_values.max()

print("Range of values in bin 0:", bin_0_min, "---", bin_0_max)
print('\n\n', application_df['ASK_AMT_Binned'].value_counts()[application_df['ASK_AMT_Binned'].value_counts() >= 50])
# Out:
# Range of values in bin 0: 148183962 --- 150830465
#
#
#  ASK_AMT_Binned
# 0    33857
# 1      138
# 2       54
# Name: count, dtype: int64

# %%
# Drop non-beneficial ID columns

application_df = application_df[application_df['ASK_AMT'] <= 15000000]
application_df.drop(columns=['EIN', 'NAME'], inplace = True)
application_df.head(1)
# Out:
# <ipython-input-4-116550322d04>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   application_df.drop(columns=['EIN', 'NAME'], inplace = True)
#   APPLICATION_TYPE  AFFILIATION CLASSIFICATION    USE_CASE ORGANIZATION  \
# 0              T10  Independent          C1000  ProductDev  Association
#
#    STATUS INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL  \
# 0       1          0                      N     5000              1
#
#    ASK_AMT_Binned
# 0               0

# %%
# Getting number of uniqeu values for each column

application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              70
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8425
# IS_SUCCESSFUL                2
# ASK_AMT_Binned               2
# dtype: int64

# %%
# Looking into APPLICATION_TYPE and each values for each category

application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3     26759
# T4      1541
# T6      1216
# T5      1168
# T19     1065
# T8       737
# T7       724
# T10      528
# T9       122
# T13       66
# T12       26
# T2        16
# T25        3
# T29        2
# T15        2
# T14        1
# T17        1
# Name: count, dtype: int64

# %%
# Iterates through columns

for column in application_df.columns:
    if application_df[column].nunique() > 10:
        print('Number of datapoints for each unique value in column', column, 'is', application_df[column].value_counts())
# Out:
# Number of datapoints for each unique value in column APPLICATION_TYPE is APPLICATION_TYPE
# T3     26759
# T4      1541
# T6      1216
# T5      1168
# T19     1065
# T8       737
# T7       724
# T10      528
# T9       122
# T13       66
# T12       26
# T2        16
# T25        3
# T29        2
# T15        2
# T14        1
# T17        1
# Name: count, dtype: int64
# Number of datapoints for each unique value in column CLASSIFICATION is CLASSIFICATION
# C1000    17092
# C2000     6039
# C1200     4807
# C3000     1913
# C2100     1880
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 70, dtype: int64
# Number of datapoints for each unique value in column ASK_AMT is ASK_AMT
# 5000     25398
# 15583        3
# 10478        3
# 6725         3
# 63981        3
#          ...
# 51641        1
# 85869        1
# 12426        1
# 16406        1
# 20197        1
# Name: count, Length: 8425, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced

cutoff_app = 500

app_type_count = application_df['APPLICATION_TYPE'].value_counts()
application_types_to_replace = app_type_count[app_type_count < cutoff_app].index.to_list()


# Replacing rare values with Other
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app, 'Other')

application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       26759
# T4        1541
# T6        1216
# T5        1168
# T19       1065
# T8         737
# T7         724
# T10        528
# Other      239
# Name: count, dtype: int64

# %%
# Look into CLASSIFICATION column and its value counts

application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17092
# C2000     6039
# C1200     4807
# C3000     1913
# C2100     1880
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 70, dtype: int64

# %%
# Look at value counts > 1

application_df['CLASSIFICATION'].value_counts()[application_df['CLASSIFICATION'].value_counts() > 1]
# Out:
# CLASSIFICATION
# C1000    17092
# C2000     6039
# C1200     4807
# C3000     1913
# C2100     1880
# C7000      774
# C1700      282
# C4000      194
# C5000      116
# C1270      113
# C2700      104
# C2800       94
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C2300       32
# C7200       31
# C1240       30
# C8000       19
# C7120       18
# C1500       15
# C6000       15
# C1800       14
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C0           3
# C2710        3
# C1234        2
# C1267        2
# C1246        2
# C1256        2
# C3200        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced

cutoff_class = 1000

class_count = application_df['CLASSIFICATION'].value_counts()
classifications_to_replace = class_count[class_count < cutoff_class].index.to_list()


# Replacing rare values with Other

for classes in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(classes, 'Other')

application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17092
# C2000     6039
# C1200     4807
# Other     2246
# C3000     1913
# C2100     1880
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric

application_df = pd.get_dummies(application_df, dtype=int)
application_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  ASK_AMT_Binned  APPLICATION_TYPE_Other  \
# 0       1     5000              1               0                       0
# 1       1   108590              1               0                       0
# 2       1     5000              0               0                       0
# 3       1     6692              1               0                       0
# 4       1   142590              1               0                       0
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                     1                     0                    0
# 1                     0                     0                    1
# 2                     0                     0                    0
# 3                     0                     0                    1
# 4                     0                     0                    1
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  ...  INCOME_AMT_1-9999  \
# 0                    0                    0  ...                  0
# 1                    0                    0  ...                  1
# 2                    0                    1  ...                  0
# 3                    0                    0  ...                  0
# 4                    0                    0  ...                  0
#
#    INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  INCOME_AMT_10M-50M  \
# 0                       0                         0                   0
# 1                       0                         0                   0
# 2                       0                         0                   0
# 3                       1                         0                   0
# 4                       0                         1                   0
#
#    INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  INCOME_AMT_50M+  \
# 0                 0                       0                0
# 1                 0                       0                0
# 2                 0                       0                0
# 3                 0                       0                0
# 4                 0                       0                0
#
#    INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0                  0                         1                         0
# 1                  0                         1                         0
# 2                  0                         1                         0
# 3                  0                         1                         0
# 4                  0                         1                         0
#
# [5 rows x 45 columns]

# %%
# Splitting data into features (X) and target (y)

X = application_df.drop(columns=['IS_SUCCESSFUL'])
y = application_df['IS_SUCCESSFUL']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Create standard scaler instane, fitting it, and scaling it

scaler = StandardScaler()

X_scaler = scaler.fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model and compile

nn = tf.keras.models.Sequential()

nn.add(tf.keras.layers.Dense(units = 30, activation = 'relu', input_shape = (X_train_scaled.shape[1],)))
nn.add(tf.keras.layers.Dense(units = 15, activation = 'relu'))
nn.add(tf.keras.layers.Dense(units = 15, activation = 'relu'))
nn.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

nn.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 30)                1350
#
#  dense_1 (Dense)             (None, 15)                465
#
#  dense_2 (Dense)             (None, 15)                240
#
#  dense_3 (Dense)             (None, 1)                 16
#
# =================================================================
# Total params: 2071 (8.09 KB)
# Trainable params: 2071 (8.09 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Creating callback instances to be called

callbacks = ModelCheckpoint(filepath = 'model_weights_epochs_{epoch:02d}.weights.h5', save_weights_only = True,
                           save_freq = 5)
# Train model

fit_model = nn.fit(X_train_scaled, y_train, epochs= 100, validation_split = 0.25, verbose = 1, callbacks = callbacks)

loss, accuracy = nn.evaluate(X_test_scaled, y_test, verbose = 2)

print('Accuracy is:', accuracy, '\nLoss is:', loss)

nn.save('AlphabetSoupCharity.h5')
# Out:
# Epoch 1/100
# 558/558 [==============================] - 8s 11ms/step - loss: 0.5825 - accuracy: 0.7100 - val_loss: 0.5623 - val_accuracy: 0.7262
# Epoch 2/100
# 558/558 [==============================] - 5s 8ms/step - loss: 0.5575 - accuracy: 0.7260 - val_loss: 0.5569 - val_accuracy: 0.7289
# Epoch 3/100
# 558/558 [==============================] - 6s 10ms/step - loss: 0.5539 - accuracy: 0.7281 - val_loss: 0.5556 - val_accuracy: 0.7296
# Epoch 4/100
# 558/558 [==============================] - 8s 14ms/step - loss: 0.5518 - accuracy: 0.7286 - val_loss: 0.5551 - val_accuracy: 0.7311
# Epoch 5/100
# 558/558 [==============================] - 5s 9ms/step - loss: 0.5501 - accuracy: 0.7301 - val_loss: 0.5550 - val_accuracy: 0.7302
# Epoch 6/100
# 558/558 [==============================] - 6s 11ms/step - loss: 0.5490 - accuracy: 0.7317 - val_loss: 0.5535 - val_accuracy: 0.7292
# Epoch 7/100
# 558/558 [==============================] - 5s 9ms/step - loss: 0.5483 - accuracy: 0.7311 - val_loss: 0.5522 - val_accuracy: 0.7306
# Epoch 8/100
# 558/558 [==============================] - 6s 10ms/step - loss: 0.5476 - accuracy: 0.7314 - val_loss: 0.5507 - val_accuracy: 0.7323
# Epoch 9/100
# 558/558 [==============================] - 7s 13ms/step - loss: 0.5466 - accuracy: 0.7338 - val_loss: 0.5529 - val_accuracy: 0.7326
# Epoch 10/100
# 558/558 [==============================] - 9s 16ms/step - loss: 0.5459 - accuracy: 0.7334 - val_loss: 0.5526 - val_accuracy: 0.7304
# Epoch 11/100
# 558/558 [==============================] - 6s 10ms/step - loss: 0.5458 - accuracy: 0.7327 - val_loss: 0.5522 - val_accuracy: 0.7311
# Epoch 12/100
# 558/558 [==============================] - 8s 14ms/step - loss: 0.5450 - accuracy: 0.7338 - val_loss: 0.5515 - val_accuracy: 0.7316
# Epoch 13/100
# 558/558 [==============================] - 6s 10ms/step - loss: 0.5446 - accuracy: 0.7318 - val_loss: 0.5526 - val_accuracy: 0.7267
# Epoch 14/100
# 558/558 [==============================] - 5s 10ms/step - loss: 0.5436 - accuracy: 0.7339 - val_loss: 0.5516 - val_accuracy: 0.7329
# Epoch 15/100
# 558/558 [==============================] - 9s 16ms/step - loss: 0.5439 - accuracy: 0.7352 - val_loss: 0.5531 - val_accuracy: 0.7321
# Epoch 16/100
# 558/558 [==============================] - 7s 13ms/step - loss: 0.5436 - accuracy: 0.7354 - val_loss: 0.5511 - val_accuracy: 0.7329
# Epoch 17/100
# 558/558 [==============================] - 5s 9ms/step - loss: 0.5432 - accuracy: 0.7350 - val_loss: 0.5515 - val_accuracy: 0.7329
# Epoch 18/100
# 558/558 [==============================] - 5s 8ms/step - loss: 0.5431 - accuracy: 0.7343 - val_loss: 0.5548 - val_accuracy: 0.7307
# Epoch 19/100
# 558/558 [==============================] - 6s 10ms/step - loss: 0.5425 - accuracy: 0.7347 - val_loss: 0.5525 - val_accuracy: 0.7323
# Epoch 20/100
# 558/558 [==============================] - 5s 9ms/step - loss: 0.5422 - accuracy: 0.7353 - val_loss: 0.5514 - val_accuracy: 0.7319
# Epoch 21/100
# 558/558 [==============================] - 8s 15ms/step - loss: 0.5419 - accuracy: 0.7345 - val_loss: 0.5521 - val_accuracy: 0.7323
# Epoch 22/100
# 558/558 [==============================] - 6s 10ms/step - loss: 0.5411 - accuracy: 0.7365 - val_loss: 0.5512 - val_accuracy: 0.7307
# Epoch 23/100
# 558/558 [==============================] - 8s 14ms/step - loss: 0.5410 - accuracy: 0.7357 - val_loss: 0.5504 - val_accuracy: 0.7307
# Epoch 24/100
# 558/558 [==============================] - 6s 10ms/step - loss: 0.5408 - accuracy: 0.7348 - val_loss: 0.5507 - val_accuracy: 0.7319
# Epoch 25/100
# 558/558 [==============================] - 6s 10ms/step - loss: 0.5408 - accuracy: 0.7354 - val_loss: 0.5522 - val_accuracy: 0.7324
# Epoch 26/100
# 558/558 [==============================] - 7s 13ms/step - loss: 0.5404 - accuracy: 0.7373 - val_loss: 0.5517 - val_accuracy: 0.7324
# Epoch 27/100
# 558/558 [==============================] - 7s 13ms/step - loss: 0.5402 - accuracy: 0.7375 - val_loss: 0.5512 - val_accuracy: 0.7309
# Epoch 28/100
# 558/558 [==============================] - 6s 11ms/step - loss: 0.5395 - accuracy: 0.7364 - val_loss: 0.5515 - val_accuracy: 0.7323
# Epoch 29/100
# 558/558 [==============================] - 9s 16ms/step - loss: 0.5398 - accuracy: 0.7378 - val_loss: 0.5513 - val_accuracy: 0.7316
# Epoch 30/100
# 558/558 [==============================] - 6s 10ms/step - loss: 0.5398 - accuracy: 0.7357 - val_loss: 0.5512 - val_accuracy: 0.7302
# Epoch 31/100
# 558/558 [==============================] - 9s 17ms/step - loss: 0.5394 - accuracy: 0.7373 - val_loss: 0.5506 - val_accuracy: 0.7307
# Epoch 32/100
# 558/558 [==============================] - 6s 11ms/step - loss: 0.5388 - accuracy: 0.7384 - val_loss: 0.5536 - val_accuracy: 0.7314
# Epoch 33/100
# 558/558 [==============================] - 9s 16ms/step - loss: 0.5389 - accuracy: 0.7377 - val_loss: 0.5517 - val_accuracy: 0.7318
# Epoch 34/100
# 558/558 [==============================] - 6s 10ms/step - loss: 0.5388 - accuracy: 0.7366 - val_loss: 0.5508 - val_accuracy: 0.7302
# Epoch 35/100
# 558/558 [==============================] - 7s 12ms/step - loss: 0.5390 - accuracy: 0.7374 - val_loss: 0.5515 - val_accuracy: 0.7314
# Epoch 36/100
# 558/558 [==============================] - 6s 11ms/step - loss: 0.5384 - accuracy: 0.7371 - val_loss: 0.5522 - val_accuracy: 0.7324
# Epoch 37/100
# 558/558 [==============================] - 9s 15ms/step - loss: 0.5384 - accuracy: 0.7372 - val_loss: 0.5528 - val_accuracy: 0.7329
# Epoch 38/100
# 558/558 [==============================] - 8s 14ms/step - loss: 0.5384 - accuracy: 0.7372 - val_loss: 0.5514 - val_accuracy: 0.7333
# Epoch 39/100
# 558/558 [==============================] - 7s 12ms/step - loss: 0.5380 - accuracy: 0.7376 - val_loss: 0.5522 - val_accuracy: 0.7316
# Epoch 40/100
# 558/558 [==============================] - 5s 10ms/step - loss: 0.5381 - accuracy: 0.7388 - val_loss: 0.5515 - val_accuracy: 0.7299
# Epoch 41/100
# 558/558 [==============================] - 10s 17ms/step - loss: 0.5376 - accuracy: 0.7384 - val_loss: 0.5527 - val_accuracy: 0.7307
# Epoch 42/100
# 558/558 [==============================] - 6s 10ms/step - loss: 0.5382 - accuracy: 0.7372 - val_loss: 0.5519 - val_accuracy: 0.7329
# Epoch 43/100
# 558/558 [==============================] - 6s 11ms/step - loss: 0.5372 - accuracy: 0.7382 - val_loss: 0.5541 - val_accuracy: 0.7312
# Epoch 44/100
# 558/558 [==============================] - 7s 13ms/step - loss: 0.5376 - accuracy: 0.7372 - val_loss: 0.5523 - val_accuracy: 0.7309
# Epoch 45/100
# 558/558 [==============================] - 7s 13ms/step - loss: 0.5374 - accuracy: 0.7371 - val_loss: 0.5543 - val_accuracy: 0.7318
# Epoch 46/100
# 558/558 [==============================] - 6s 11ms/step - loss: 0.5366 - accuracy: 0.7382 - val_loss: 0.5551 - val_accuracy: 0.7309
# Epoch 47/100
# 558/558 [==============================] - 6s 11ms/step - loss: 0.5369 - accuracy: 0.7389 - val_loss: 0.5549 - val_accuracy: 0.7287
# Epoch 48/100
# 558/558 [==============================] - 5s 10ms/step - loss: 0.5366 - accuracy: 0.7384 - val_loss: 0.5511 - val_accuracy: 0.7312
# Epoch 49/100
# 558/558 [==============================] - 5s 8ms/step - loss: 0.5368 - accuracy: 0.7385 - val_loss: 0.5545 - val_accuracy: 0.7312
# Epoch 50/100
# 558/558 [==============================] - 7s 12ms/step - loss: 0.5364 - accuracy: 0.7376 - val_loss: 0.5557 - val_accuracy: 0.7311
# Epoch 51/100
# 558/558 [==============================] - 5s 9ms/step - loss: 0.5364 - accuracy: 0.7386 - val_loss: 0.5522 - val_accuracy: 0.7307
# Epoch 52/100
# 558/558 [==============================] - 8s 15ms/step - loss: 0.5357 - accuracy: 0.7400 - val_loss: 0.5566 - val_accuracy: 0.7307
# Epoch 53/100
# 558/558 [==============================] - 7s 12ms/step - loss: 0.5363 - accuracy: 0.7392 - val_loss: 0.5566 - val_accuracy: 0.7314
# Epoch 54/100
# 558/558 [==============================] - 10s 19ms/step - loss: 0.5359 - accuracy: 0.7386 - val_loss: 0.5543 - val_accuracy: 0.7306
# Epoch 55/100
# 558/558 [==============================] - 6s 11ms/step - loss: 0.5356 - accuracy: 0.7391 - val_loss: 0.5551 - val_accuracy: 0.7309
# Epoch 56/100
# 558/558 [==============================] - 7s 13ms/step - loss: 0.5358 - accuracy: 0.7386 - val_loss: 0.5537 - val_accuracy: 0.7314
# Epoch 57/100
# 558/558 [==============================] - 6s 10ms/step - loss: 0.5358 - accuracy: 0.7390 - val_loss: 0.5553 - val_accuracy: 0.7301
# Epoch 58/100
# 558/558 [==============================] - 9s 17ms/step - loss: 0.5356 - accuracy: 0.7377 - val_loss: 0.5557 - val_accuracy: 0.7312
# Epoch 59/100
# 558/558 [==============================] - 5s 10ms/step - loss: 0.5358 - accuracy: 0.7383 - val_loss: 0.5541 - val_accuracy: 0.7309
# Epoch 60/100
# 558/558 [==============================] - 7s 12ms/step - loss: 0.5350 - accuracy: 0.7394 - val_loss: 0.5565 - val_accuracy: 0.7316
# Epoch 61/100
# 558/558 [==============================] - 9s 16ms/step - loss: 0.5350 - accuracy: 0.7391 - val_loss: 0.5573 - val_accuracy: 0.7312
# Epoch 62/100
# 558/558 [==============================] - 9s 15ms/step - loss: 0.5347 - accuracy: 0.7389 - val_loss: 0.5554 - val_accuracy: 0.7302
# Epoch 63/100
# 558/558 [==============================] - 9s 17ms/step - loss: 0.5349 - accuracy: 0.7382 - val_loss: 0.5573 - val_accuracy: 0.7299
# Epoch 64/100
# 558/558 [==============================] - 6s 10ms/step - loss: 0.5351 - accuracy: 0.7390 - val_loss: 0.5569 - val_accuracy: 0.7314
# Epoch 65/100
# 558/558 [==============================] - 6s 11ms/step - loss: 0.5355 - accuracy: 0.7395 - val_loss: 0.5559 - val_accuracy: 0.7321
# Epoch 66/100
# 558/558 [==============================] - 6s 11ms/step - loss: 0.5351 - accuracy: 0.7385 - val_loss: 0.5562 - val_accuracy: 0.7291
# Epoch 67/100
# 558/558 [==============================] - 9s 16ms/step - loss: 0.5347 - accuracy: 0.7385 - val_loss: 0.5572 - val_accuracy: 0.7307
# Epoch 68/100
# 558/558 [==============================] - 5s 8ms/step - loss: 0.5342 - accuracy: 0.7393 - val_loss: 0.5570 - val_accuracy: 0.7326
# Epoch 69/100
# 558/558 [==============================] - 5s 8ms/step - loss: 0.5347 - accuracy: 0.7402 - val_loss: 0.5559 - val_accuracy: 0.7319
# Epoch 70/100
# 558/558 [==============================] - 6s 10ms/step - loss: 0.5347 - accuracy: 0.7399 - val_loss: 0.5554 - val_accuracy: 0.7291
# Epoch 71/100
# 558/558 [==============================] - 5s 8ms/step - loss: 0.5337 - accuracy: 0.7407 - val_loss: 0.5575 - val_accuracy: 0.7299
# Epoch 72/100
# 558/558 [==============================] - 5s 10ms/step - loss: 0.5347 - accuracy: 0.7401 - val_loss: 0.5583 - val_accuracy: 0.7314
# Epoch 73/100
# 558/558 [==============================] - 5s 9ms/step - loss: 0.5344 - accuracy: 0.7399 - val_loss: 0.5571 - val_accuracy: 0.7321
# Epoch 74/100
# 558/558 [==============================] - 5s 8ms/step - loss: 0.5338 - accuracy: 0.7393 - val_loss: 0.5589 - val_accuracy: 0.7318
# Epoch 75/100
# 558/558 [==============================] - 6s 11ms/step - loss: 0.5337 - accuracy: 0.7402 - val_loss: 0.5557 - val_accuracy: 0.7316
# Epoch 76/100
# 558/558 [==============================] - 5s 8ms/step - loss: 0.5338 - accuracy: 0.7399 - val_loss: 0.5596 - val_accuracy: 0.7329
# Epoch 77/100
# 558/558 [==============================] - 5s 9ms/step - loss: 0.5336 - accuracy: 0.7396 - val_loss: 0.5593 - val_accuracy: 0.7282
# Epoch 78/100
# 558/558 [==============================] - 6s 11ms/step - loss: 0.5335 - accuracy: 0.7404 - val_loss: 0.5584 - val_accuracy: 0.7291
# Epoch 79/100
# 558/558 [==============================] - 5s 9ms/step - loss: 0.5344 - accuracy: 0.7392 - val_loss: 0.5572 - val_accuracy: 0.7311
# Epoch 80/100
# 558/558 [==============================] - 5s 9ms/step - loss: 0.5330 - accuracy: 0.7399 - val_loss: 0.5588 - val_accuracy: 0.7296
# Epoch 81/100
# 558/558 [==============================] - 5s 9ms/step - loss: 0.5337 - accuracy: 0.7410 - val_loss: 0.5574 - val_accuracy: 0.7328
# Epoch 82/100
# 558/558 [==============================] - 5s 8ms/step - loss: 0.5333 - accuracy: 0.7409 - val_loss: 0.5584 - val_accuracy: 0.7277
# Epoch 83/100
# 558/558 [==============================] - 6s 11ms/step - loss: 0.5327 - accuracy: 0.7399 - val_loss: 0.5581 - val_accuracy: 0.7324
# Epoch 84/100
# 558/558 [==============================] - 5s 8ms/step - loss: 0.5332 - accuracy: 0.7392 - val_loss: 0.5595 - val_accuracy: 0.7318
# Epoch 85/100
# 558/558 [==============================] - 5s 8ms/step - loss: 0.5331 - accuracy: 0.7395 - val_loss: 0.5577 - val_accuracy: 0.7311
# Epoch 86/100
# 558/558 [==============================] - 6s 10ms/step - loss: 0.5332 - accuracy: 0.7400 - val_loss: 0.5585 - val_accuracy: 0.7314
# Epoch 87/100
# 558/558 [==============================] - 5s 8ms/step - loss: 0.5336 - accuracy: 0.7399 - val_loss: 0.5594 - val_accuracy: 0.7323
# Epoch 88/100
# 558/558 [==============================] - 5s 10ms/step - loss: 0.5329 - accuracy: 0.7409 - val_loss: 0.5599 - val_accuracy: 0.7328
# Epoch 89/100
# 558/558 [==============================] - 5s 9ms/step - loss: 0.5329 - accuracy: 0.7398 - val_loss: 0.5584 - val_accuracy: 0.7302
# Epoch 90/100
# 558/558 [==============================] - 5s 8ms/step - loss: 0.5328 - accuracy: 0.7412 - val_loss: 0.5623 - val_accuracy: 0.7324
# Epoch 91/100
# 558/558 [==============================] - 6s 11ms/step - loss: 0.5323 - accuracy: 0.7422 - val_loss: 0.5585 - val_accuracy: 0.7316
# Epoch 92/100
# 558/558 [==============================] - 5s 8ms/step - loss: 0.5328 - accuracy: 0.7414 - val_loss: 0.5596 - val_accuracy: 0.7319
# Epoch 93/100
# 558/558 [==============================] - 5s 8ms/step - loss: 0.5329 - accuracy: 0.7407 - val_loss: 0.5592 - val_accuracy: 0.7307
# Epoch 94/100
# 558/558 [==============================] - 6s 10ms/step - loss: 0.5324 - accuracy: 0.7407 - val_loss: 0.5618 - val_accuracy: 0.7275
# Epoch 95/100
# 558/558 [==============================] - 5s 8ms/step - loss: 0.5324 - accuracy: 0.7408 - val_loss: 0.5611 - val_accuracy: 0.7296
# Epoch 96/100
# 558/558 [==============================] - 5s 9ms/step - loss: 0.5322 - accuracy: 0.7398 - val_loss: 0.5593 - val_accuracy: 0.7321
# Epoch 97/100
# 558/558 [==============================] - 6s 10ms/step - loss: 0.5327 - accuracy: 0.7417 - val_loss: 0.5604 - val_accuracy: 0.7311
# Epoch 98/100
# 558/558 [==============================] - 4s 8ms/step - loss: 0.5317 - accuracy: 0.7419 - val_loss: 0.5625 - val_accuracy: 0.7319
# Epoch 99/100
# 558/558 [==============================] - 6s 10ms/step - loss: 0.5322 - accuracy: 0.7416 - val_loss: 0.5628 - val_accuracy: 0.7323
# Epoch 100/100
# 558/558 [==============================] - 5s 8ms/step - loss: 0.5322 - accuracy: 0.7409 - val_loss: 0.5625 - val_accuracy: 0.7312
# 319/319 - 1s - loss: 0.5608 - accuracy: 0.7335 - 600ms/epoch - 2ms/step
# Accuracy is: 0.7334706783294678
# Loss is: 0.5607972741127014
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
